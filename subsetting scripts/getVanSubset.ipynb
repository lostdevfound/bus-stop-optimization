# %%
import pandas as pd

# %%
df = pd.read_csv("2016_92-151_XBB.csv",encoding = "ISO–8859–1")
# Out:
# C:\Program Files\Python37\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    DBuid/IDidu   DBpop2016/IDpop2016   DBtdwell2016/IDtlog2016  \
# 0  10020117004                  36.0                      13.0
# 1  10020117003                  35.0                      21.0
# 2  10020117008                  46.0                      28.0
# 3  10010746008                  30.0                      28.0
# 4  10010746010                  26.0                      44.0
#
#     DBurdwell2016/IDrh2016   DBarea2016/IDsup2016  DBir2016/IDri2016  \
# 0                     10.0                 0.6124                  F
# 1                     16.0                 3.8578                  F
# 2                     21.0                 0.3800                  F
# 3                     15.0                 7.7079                  F
# 4                     17.0                 3.9179                  F
#
#     DAuid/ADidu   DArplamx/ADlamx   DArplamy/ADlamy   DArplat/Adlat  ...  \
# 0      10020117      8.852175e+06      1.980863e+06       46.932976  ...
# ...

# %%
df.columns
# Out:
# Index(['DBuid/IDidu', ' DBpop2016/IDpop2016', ' DBtdwell2016/IDtlog2016',
#        ' DBurdwell2016/IDrh2016', ' DBarea2016/IDsup2016',
#        ' DBir2016/IDri2016', ' DAuid/ADidu', ' DArplamx/ADlamx',
#        ' DArplamy/ADlamy', ' DArplat/Adlat', ' DArplong/ADlong',
#        ' PRuid/PRidu', ' PRname/PRnom', ' PRename/PRanom', ' PRfname/PRfnom',
#        ' PReabbr/PRaabbrev', ' PRfabbr/PRfabbrev', ' FEDuid/CEFidu',
#        ' FEDname/CEFnom', ' ERuid/REidu', ' ERname/REnom', ' CDuid/DRidu',
#        ' CDname/DRnom', ' CDtype/DRgenre', ' ADAuid/ADAidu', ' ADAcode',
#        ' CSDuid/SDRidu', ' CSDname/SDRnom', ' CSDtype/SDRgenre',
#        ' SACtype/CSSgenre', ' SACcode/CSScode', ' CCSuid/SRUidu',
#        ' CCSname/SRUnom', ' DPLuid/LDidu', ' DPLname/LDnom',
#        ' DPLtype/LDgenre', ' CMAPuid/RMRPidu', ' CMAuid/RMRidu',
#        ' CMAname/RMRnom', ' CMAtype/RMRgenre', ' CTuid/SRidu',
#        ' CTcode/SRcode', ' CTname/SRnom', ' POPCTRRAPuid/CTRPOPRRPidu',
# ...

# %%
vandf = df[df[" CCSname/SRUnom"]=="Vancouver"]

# %%
vandf
# Out:
#         DBuid/IDidu   DBpop2016/IDpop2016   DBtdwell2016/IDtlog2016  \
# 445092  59151369002                 244.0                      71.0
# 445094  59151364002                 161.0                      56.0
# 445095  59151373002                 347.0                     140.0
# 445098  59151365003                 136.0                      52.0
# 445153  59151449001                 134.0                      83.0
# 445155  59151365002                 117.0                      48.0
# 445156  59150431006                 133.0                      55.0
# 445157  59151369001                 316.0                     106.0
# 445158  59151367002                 123.0                      41.0
# 445159  59151366003                 122.0                      43.0
# 445161  59151448002                 110.0                      42.0
# 445162  59151366004                   0.0                       0.0
# 445163  59151367001                  81.0                      34.0
# ...

# %%
vandf.to_csv("vancouverSubset.csv",encoding="ISO–8859–1")
